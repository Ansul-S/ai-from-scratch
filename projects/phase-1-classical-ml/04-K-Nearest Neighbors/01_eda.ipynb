# %% [markdown]
# ### EDA

# %% [markdown]
# #### Set-up and dataset loading

# %%
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np

iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
df['species'] = df['target'].map({0: 'setosa', 1: 'versicolor', 2: 'virginica'})

print(df.shape)
print(df.dtypes)
df.head()
# Out:
# (150, 6)
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# species               object
# dtype: object
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target species
# 0       0  setosa
# 1       0  setosa
# 2       0  setosa
# 3       0  setosa
# 4       0  setosa

# %%
print(df.describe())
print("\nClass distribution:")
print(df['species'].value_counts())
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000
#
# Class distribution:
# species
# setosa        50
# versicolor    50
# ...

# %% [markdown]
# ### Plots

# %% [markdown]
# #### Pair plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.pairplot(df, hue='species', vars=iris.feature_names, 
             plot_kws={'alpha': 0.7}, diag_kind='kde')
plt.suptitle('Iris Feature Pairplot', y=1.02)
plt.savefig('results/feature_pairplot.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

for i, feature in enumerate(iris.feature_names):
    axes[i].boxplot(
        [df[df['species'] == s][feature].values for s in ['setosa', 'versicolor', 'virginica']],
        labels=['setosa', 'versicolor', 'virginica']
    )
    axes[i].set_title(feature)
    axes[i].tick_params(axis='x', rotation=15)

plt.suptitle('Feature Distributions by Class')
plt.tight_layout()
plt.savefig('results/class_distribution.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# /var/folders/k8/ncpzqds97lb86kwyp4d1byq00000gn/T/ipykernel_49571/3822841732.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[i].boxplot(
# /var/folders/k8/ncpzqds97lb86kwyp4d1byq00000gn/T/ipykernel_49571/3822841732.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[i].boxplot(
# /var/folders/k8/ncpzqds97lb86kwyp4d1byq00000gn/T/ipykernel_49571/3822841732.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   axes[i].boxplot(
# ...
